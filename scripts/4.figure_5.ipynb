# %%
from lxh_prediction.plot import plot_curve, plt
from lxh_prediction.curves_auc import auROCExp, auPRExp
from lxh_prediction.curves_cost import (
    FutureCostExp,
    SensitivityCostExp,
    NeedsMissRateExp,
    CostMissRateExp,
)

# %%
# Figure 5a AUC

exp = auROCExp(plt.figure(figsize=(6, 6), dpi=300), retrain=False)
exp.run("ML Model", "LightGBMModel", "top20_non_lab")
exp.run("ML+FPG Model", "LightGBMModel", "FPG")
exp.run("ML+2hPG Model", "LightGBMModel", "2hPG")
exp.run("ML+HbA1c Model", "LightGBMModel", "HbA1c")

# Random
plot_curve(
    (0, 1),
    (0, 1),
    ylim=(0, 1),
    xlabel="1-Specificity",
    ylabel="Sensitivity",
    color="navy",
    lw=2,
    linestyle="--",
    name="Random",
)
exp.plot()

exp.save("figure5a")
# Out:
# [0.69058641 0.72956975 0.71502412 0.68531333 0.70414349]
# [0.90042507 0.90814606 0.89138172 0.90378632 0.88353367]
# [0.88678871 0.90322607 0.93360109 0.89903582 0.92643054]
# [0.79264971 0.81901984 0.82859403 0.7947493  0.82896034]

# %%
# Figure 5b auPR

exp = auPRExp(plt.figure(figsize=(6, 6), dpi=300), retrain=False)
exp.run("ML Model", "LightGBMModel", "top20_non_lab")
exp.run("ML+FPG Model", "LightGBMModel", "FPG")
exp.run("ML+2hPG Model", "LightGBMModel", "2hPG")
exp.run("ML+HbA1c Model", "LightGBMModel", "HbA1c")
exp.plot()

plt.legend(loc="lower left")
exp.save("figure5b")

# %%
# Figure 5c
exp = NeedsMissRateExp(retrain=False)

exp.xlim = (0, 1)
exp.run("ML Model", "LightGBMModel", "top20_non_lab")
exp.run("ML+FPG Model", "LightGBMModel", "FPG")
exp.run("ML+2hPG Model", "LightGBMModel", "2hPG")
exp.run("ML+HbA1c Model", "LightGBMModel", "HbA1c")

exp.plot()
plt.legend(loc="upper right")
exp.save("figure5c")
# Out:
# /home/longc/anaconda3/envs/py38/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# /home/longc/anaconda3/envs/py38/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# /home/longc/anaconda3/envs/py38/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# /home/longc/anaconda3/envs/py38/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %%
# Figure 5d

exp = CostMissRateExp(retrain=False)
exp.ylim = (0, 120)
exp.xlim = (0, 1)

exp.run("ML Model", "LightGBMModel", "top20_non_lab")
exp.run("ML+FPG Model", "LightGBMModel", "FPG")
exp.run("ML+2hPG Model", "LightGBMModel", "2hPG")
exp.run("ML+HbA1c Model", "LightGBMModel", "HbA1c")

exp.plot()
plt.legend(loc="upper right")
exp.save("figure5d")
# Out:
# /home/longc/anaconda3/envs/py38/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# /home/longc/anaconda3/envs/py38/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# /home/longc/anaconda3/envs/py38/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# /home/longc/anaconda3/envs/py38/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %%
# Figure 5e

exp = SensitivityCostExp(retrain=False)
exp.xlim = (0, 150)
exp.ylim = (0, 1)

exp.run("ML Model", "LightGBMModel", "top20_non_lab")
exp.run("ML+FPG Model", "LightGBMModel", "FPG")
exp.run("ML+2hPG Model", "LightGBMModel", "2hPG")
exp.run("ML+HbA1c Model", "LightGBMModel", "HbA1c")
exp.plot()
plt.legend(loc="lower right")
exp.save("figure5e")
# Out:
# 0.03617210682492582
# (0.03617210682492582, 150)
# 18.19
# (18.19, 150)
# 51.06
# (51.06, 150)
# 92.45999999999998
# (92.45999999999998, 150)
# 0.03617210682492582
# 0.03617210682492582 0.03617210682492582 7.5
# 18.19
# 18.19 11.809999999999999 7.5
# 51.06
# 51.06 8.939999999999998 7.5
# 92.45999999999998
# 92.45999999999998 2.4599999999999795 7.5
# 0.03617210682492582
# 0.03617210682492582 0.03617210682492582 7.5
# 18.19
# 18.19 11.809999999999999 7.5
# 51.06
# 51.06 8.939999999999998 7.5
# 92.45999999999998
# 92.45999999999998 2.4599999999999795 7.5

# %%
# Figure 5f

exp = FutureCostExp(compare_to_all=True, retrain=False)
exp.xlim = (0, 150)
exp.ylim = (0, 700)

exp.run("ML Model", "LightGBMModel", "top20_non_lab")
exp.run("ML+FPG Model", "LightGBMModel", "FPG")
exp.run("ML+2hPG Model", "LightGBMModel", "2hPG")
exp.run("ML+HbA1c Model", "LightGBMModel", "HbA1c")

exp.plot()
plt.legend(loc="upper right")
exp.save("figure5f")
# Out:
# 0.03617210682492582
# (0.03617210682492582, 150)
# 18.19
# (18.19, 150)
# 51.06
# (51.06, 150)
# 92.45999999999998
# (92.45999999999998, 150)
# 0.03617210682492582
# 0.03617210682492582 0.03617210682492582 7.5
# 18.19
# 18.19 11.809999999999999 7.5
# 51.06
# 51.06 8.939999999999998 7.5
# 92.45999999999998
# 92.45999999999998 2.4599999999999795 7.5
# 0.03617210682492582
# 0.03617210682492582 0.03617210682492582 7.5
# 18.19
# 18.19 11.809999999999999 7.5
# 51.06
# 51.06 8.939999999999998 7.5
# 92.45999999999998
# 92.45999999999998 2.4599999999999795 7.5
