# %%
from lxh_prediction.plot import plot_curve, plt
from lxh_prediction.curves_auc import auROCExp, auPRExp

# %%
exp = auROCExp(plt.figure(figsize=(6, 6), dpi=300), retrain=False)
exp.run("ML Model", "LightGBMModel", "top20_non_lab")
exp.run("Ensemble Model", "EnsembleModel", "top20_non_lab")

# Random
plot_curve(
    (0, 1),
    (0, 1),
    ylim=(0, 1),
    xlabel="1-Specificity",
    ylabel="Sensitivity",
    color="navy",
    lw=2,
    linestyle="--",
    name="Random",
)
exp.plot()

exp.save("figure_supp4a")
# Out:
# [0.69058641 0.72956975 0.71502412 0.68531333 0.70414349]
# [0.69399628 0.73534582 0.73205417 0.68520269 0.71357996]

# %%
exp = auPRExp(plt.figure(figsize=(6, 6), dpi=300), retrain=False)
exp.run("ML Model", "LightGBMModel", "top20_non_lab")
exp.run("Ensemble Model", "EnsembleModel", "top20_non_lab")
exp.plot()

plt.legend(loc="lower left")
exp.save("figure_supp4b")

# %%
exp = auROCExp(plt.figure(figsize=(6, 6), dpi=300), retrain=False)
exp.run("ML+FPG Model", "LightGBMModel", "FPG")
exp.run("Ensemble+FPG Model", "EnsembleModel", "FPG")

# Random
plot_curve(
    (0, 1),
    (0, 1),
    ylim=(0, 1),
    xlabel="1-Specificity",
    ylabel="Sensitivity",
    color="navy",
    lw=2,
    linestyle="--",
    name="Random",
)
exp.plot()

exp.save("figure_supp4c")
# Out:
# [0.90042507 0.90814606 0.89138172 0.90378632 0.88353367]
# [0.8958641  0.91456174 0.9004454  0.90900618 0.89580011]

# %%
exp = auPRExp(plt.figure(figsize=(6, 6), dpi=300), retrain=False)
exp.run("ML+FPG Model", "LightGBMModel", "FPG")
exp.run("Ensemble+FPG Model", "EnsembleModel", "FPG")
exp.plot()

plt.legend(loc="lower left")
exp.save("figure_supp4d")
